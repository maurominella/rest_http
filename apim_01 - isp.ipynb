# %% [markdown]
# # Variables definition

# %%
import os, requests, datetime
from openai import AzureOpenAI
from dotenv import load_dotenv

load_dotenv("./../config/credentials_my.env")
openai_endpoint       = os.environ["openai_endpoint"]
openai_api_key        = os.environ["openai_api_key"]
openai_api_version    = os.environ["openai_api_version"]
azure_deployment_name = os.environ["azure_deployment_name"]

apim_endpoint         = os.environ["apim_endpoint"]
apim_subscription_key = os.environ["apim_subscription_key_premium"] # apim_subscription_key_service, apim_subscription_key_standard and apim_subscription_key_premium
apim_api_version      = os.environ["apim_api_version"] # never used

# system and user message files
file_path = ".\\isp_docs\\"
system_message_path = f"{file_path}system_message.txt"
user_message_path = f"{file_path}user_message.txt"
answer_verification_path = f"{file_path}answer_verification.txt"

messages_sample = [
    {
      "role": "user",
      "content": "What is a meaning function? Please summarize in less than 20 words."
    }
]

# %% [markdown]
# # Prepare OpenAI call payload

# %%
def read_file_content(file_path: str) -> str:
    # Open and read the file
    try:
        with open(file_path, 'r') as file:
            # Read the contents of the file
            content = file.read()
            # Print the content
            return content
    except FileNotFoundError:
        print(f"The file at {file_path} was not found.")
    except IOError:
        print(f"An error occurred while reading the file at {file_path}.")


system_message = read_file_content(system_message_path)
user_message   = read_file_content(user_message_path)

messages = [
    {
      "role": "system",
      "content": system_message
    },
    {
      "role": "user",
      "content": user_message
    }
]

# print(messages)

# %% [markdown]
# # Answer Check

# %%
def check_answer(answer: str) -> str:
    messages_verification = [
        {
            "role": "user",
            "content": read_file_content(answer_verification_path).replace("<string_to_check>", answer)
        }
    ]

    url = f"{openai_endpoint}openai/deployments/{azure_deployment_name}/chat/completions?api-version={openai_api_version}"
    response_http = requests.post(url, headers = {'api-key':openai_api_key}, json = {"messages": messages_verification})

    if (int(response_http.status_code / 100))==2:
        answer = response_http.json()['choices'][0]['message']['content']
        return(answer)
    else:
        print(response_http.text)

check_answer("non lo so") # "non lo so", "è una carta prepagata nominativa"
# Out:
# 'CORRECT'

# %% [markdown]
# # Invoking Open AI via HTTP or Azure SDK

# %%
def invoke_openai(method:str="http", iterations:int=10, temperature:float=0, top_p:float=0.95, max_tokens=500):

    filename = datetime.datetime.now().strftime("%Y_%m_%d_%H_%M_logs.txt") # Format the date and time as required
    correct_count = 0
    logs = ""
           
    if method == "http":
        messages_json = {"messages": messages, "temperature": temperature, "top_p": top_p, "max_tokens": max_tokens}
        url = f"{openai_endpoint}openai/deployments/{azure_deployment_name}/chat/completions?api-version={openai_api_version}"
    elif method == "sdk":
        client = AzureOpenAI(
            azure_endpoint = openai_endpoint,
            api_key        = openai_api_key,
            api_version    = openai_api_version
        )
        messages_json = messages
        parameters = {  
            "temperature": temperature,  # Adjust the temperature value as needed  
            "top_p": top_p,  # Adjust the top_p value as needed
            "max_tokens": max_tokens
        }

    for i in range(iterations):
        if method == "http":
            response_http = requests.post(url, headers = {'api-key':openai_api_key}, json = {"messages": messages})
            if (int(response_http.status_code / 100))==2:
                answer = response_http.json()['choices'][0]['message']['content']
            else:
                print(response_http.text)
                return
                
        elif method == "sdk":
            response_sdk = client.chat.completions.create(
                model    = azure_deployment_name,
                messages = messages_json,
                **parameters
            )
            answer = response_sdk.choices[0].message.content

        answer_result = check_answer(answer)
        correct_count += 1 if answer_result == "CORRECT" else 0

        output = f">>>> {i+1} ({method}) - {answer_result}: {answer}\n"
        print(output)
        logs = f"{logs}{output}\n"
    
    statistics = f"Summary: {correct_count} correct results out of {iterations} ({correct_count/iterations*100}%)"
    
    # Write the string to the file
    with open(f"{file_path}{filename}", "w") as file:
        file.write(f"{statistics}\n=======\n{logs}")
    
    print(statistics)

# %%
# %%time

invoke_openai (method="sdk", iterations=100)
# Out:
# >>>> 1 (sdk) - WRONG: La carta Superflash è una carta prepagata nominativa ricaricabile destinata ai giovani, studenti o lavoratori, e a tutti coloro che desiderano disporre e ricevere bonifici, pagare presso gli esercizi commerciali e acquistare su Internet senza ancora possedere un conto corrente. La carta può essere sottoscritta esclusivamente da maggiorenni che possiedono un Codice Fiscale valido e che abbiano sottoscritto il Servizio a distanza e firme elettroniche - My Key. Non può essere rilasciata a minori o incapaci [1203].
#
# >>>> 2 (sdk) - CORRECT: Come Co-pilota dei Gestori di Filiale Digitale mi occupo di altri argomenti, per approfondirli consulta la Guida ai contenuti. Se vuoi chiedimi qualcos'altro e proverò a risponderti.
#
# >>>> 3 (sdk) - WRONG: La carta Superflash è una carta prepagata nominativa ricaricabile destinata ai giovani, studenti o lavoratori, e a tutti coloro che desiderano disporre e ricevere bonifici, pagare presso gli esercizi commerciali e acquistare su Internet senza ancora possedere un conto corrente. La carta può essere sottoscritta esclusivamente da maggiorenni che possiedono un Codice Fiscale valido e che abbiano sottoscritto il Servizio a distanza e firme elettroniche - My Key. Non può essere rilasciata a minori o incapaci [1203].
#
# >>>> 4 (sdk) - WRONG: La carta giovani nazionale, conosciuta anche come Superflash, è una carta prepagata nominativa ricaricabile destinata ai giovani, studenti o lavoratori, e a tutti coloro che desiderano disporre e ricevere bonifici, pagare presso gli esercizi commerciali e acquistare su Internet senza ancora possedere un conto corrente. Non può essere rilasciata a minori o incapaci. [1203]
#
# Per le carte Superflash in convenzione emesse prima del 30 settembre 2017 che beneficiano di una deroga "a tempo" sul canone annuo, alla scadenza della deroga stessa viene applicato in automatico il nuovo canone annuo pari a <b>26,90 euro</b>. Se il cliente ha ancora meno di 26 anni non pagherà il canone; al compimento dei 26 anni sarà applicato, dal mese successivo a quello di scadenza annuale della carta, il canone di <b>26,90 euro</b> (derogabile a <b>9,90 euro</b> solo attraverso un intervento in Price da parte della filiale). [1068]
#
# >>>> 5 (sdk) - WRONG: La carta Superflash è una carta prepagata nominativa ricaricabile destinata ai giovani, studenti o lavoratori, e a tutti coloro che desiderano disporre e ricevere bonifici, pagare presso gli esercizi commerciali e acquistare su Internet senza ancora possedere un conto corrente. Non può essere rilasciata a minori o incapaci. [1203]
#
# Per le carte Superflash in convenzione emesse prima del 30.09.17 che beneficiano di una deroga "a tempo" sul canone annuo, alla scadenza della deroga stessa viene applicato in automatico il nuovo canone annuo pari a <b>26,90 euro</b>. Se il cliente ha ancora meno di 26 anni non pagherà il canone; al compimento dei 26 anni sarà applicato, dal mese successivo a quello di scadenza annuale della carta, il canone di <b>26,90 euro</b> (derogabile a <b>9,90 euro</b> solo attraverso un intervento in Price da parte della filiale) [1068].
#
# >>>> 6 (sdk) - WRONG: La carta Superflash è una carta prepagata nominativa ricaricabile destinata ai giovani, studenti o lavoratori, e a tutti coloro che desiderano disporre e ricevere bonifici, pagare presso gli esercizi commerciali e acquistare su Internet senza ancora possedere un conto corrente. Non può essere rilasciata a minori o incapaci. La carta può essere sottoscritta esclusivamente da maggiorenni che possiedono un Codice Fiscale valido e che abbiano sottoscritto il Servizio a distanza e firme elettroniche - My Key [1203].
#
# >>>> 7 (sdk) - CORRECT: Come Co-pilota dei Gestori di Filiale Digitale mi occupo di altri argomenti, per approfondirli consulta la Guida ai contenuti. Se vuoi chiedimi qualcos'altro e proverò a risponderti.
#
# >>>> 8 (sdk) - CORRECT: Come Co-pilota dei Gestori di Filiale Digitale mi occupo di altri argomenti, per approfondirli consulta la Guida ai contenuti. Se vuoi chiedimi qualcos'altro e proverò a risponderti.
#
# >>>> 9 (sdk) - WRONG: La carta giovani nazionale non è menzionata nelle fonti fornite. Tuttavia, posso fornirti informazioni su alcune carte e promozioni per i giovani offerte da Intesa Sanpaolo.
#
# 1. **XME Conto e XME Card Plus**:
#    - Dal **27 maggio 2023** al **30 novembre 2023**, i giovani under 35 possono usufruire di una promozione che azzera il canone mensile base del XME Conto monointestato e il canone mensile della XME Card Plus se sottoscritta entro il **30 novembre 2023** fino alla fine del mese del compimento del trentacinquesimo anno di età [815].
#
# 2. **Superflash**:
#    - È una carta prepagata nominativa ricaricabile destinata ai giovani, studenti o lavoratori, e a tutti coloro che desiderano disporre e ricevere bonifici, pagare presso gli esercizi commerciali e acquistare su Internet senza possedere un conto corrente. Non può essere rilasciata a minori o incapaci [1203].
#
# 3. **Promozioni per i giovani**:
#    - Dal **01 marzo 2019** è stato innalzato il limite di età da 30 a 35 anni per beneficiare delle promozioni dedicate ai giovani. Le promozioni includono una riduzione di **7,50 €** sul canone totale mensile per i clienti under 35 con conto monointestato, azzeramento dell'imposta di bollo, prelievi gratuiti su sportelli automatici abilitati di altre banche area SEPA/extra SEPA, bonifici online gratuiti e azzeramento del costo per l'invio dell'estratto conto cartaceo [377].
#
# Se hai bisogno di ulteriori informazioni su altre carte o promozioni, fammelo sapere!
#
# >>>> 10 (sdk) - CORRECT: Come Co-pilota dei Gestori di Filiale Digitale mi occupo di altri argomenti, per approfondirli consulta la Guida ai contenuti. Se vuoi chiedimi qualcos'altro e proverò a risponderti.
#
# >>>> 11 (sdk) - WRONG: La carta Superflash è una carta prepagata nominativa ricaricabile destinata ai giovani, studenti o lavoratori, e a tutti coloro che desiderano disporre e ricevere bonifici, pagare presso gli esercizi commerciali e acquistare su Internet senza ancora possedere un conto corrente. Non può essere rilasciata a minori o incapaci. [1203]
#
# Per le carte Superflash in convenzione emesse prima del 30.09.17 che beneficiano di una deroga "a tempo" sul canone annuo, alla scadenza della deroga stessa viene applicato in automatico il nuovo canone annuo pari a <b>26,90 euro</b>. Se il cliente ha ancora meno di 26 anni non pagherà il canone; al compimento dei 26 anni sarà applicato, dal mese successivo a quello di scadenza annuale della carta, il canone di <b>26,90 euro</b> (derogabile a <b>9,90 euro</b> solo attraverso un intervento in Price da parte della filiale) [1068].
#
# >>>> 12 (sdk) - WRONG: La carta Superflash è una carta prepagata nominativa ricaricabile destinata ai giovani, studenti o lavoratori, e a tutti coloro che desiderano disporre e ricevere bonifici (non è possibile ricevere bonifici di importo inferiore a 1,00 euro), pagare presso gli esercizi commerciali e acquistare su Internet senza ancora possedere un conto corrente. Non può essere rilasciata a minori o incapaci. La carta può essere sottoscritta esclusivamente da maggiorenni che possiedono un Codice Fiscale valido e che abbiano sottoscritto il Servizio a distanza e firme elettroniche - My Key [1203].
#
# >>>> 13 (sdk) - CORRECT: Come Co-pilota dei Gestori di Filiale Digitale mi occupo di altri argomenti, per approfondirli consulta la Guida ai contenuti. Se vuoi chiedimi qualcos'altro e proverò a risponderti.
#
# >>>> 14 (sdk) - CORRECT: Come Co-pilota dei Gestori di Filiale Digitale mi occupo di altri argomenti, per approfondirli consulta la Guida ai contenuti. Se vuoi chiedimi qualcos'altro e proverò a risponderti.
#
# >>>> 15 (sdk) - CORRECT: Come Co-pilota dei Gestori di Filiale Digitale mi occupo di altri argomenti, per approfondirli consulta la Guida ai contenuti. Se vuoi chiedimi qualcos'altro e proverò a risponderti.
#
# >>>> 16 (sdk) - WRONG: La carta Superflash è una carta prepagata nominativa ricaricabile destinata ai giovani, studenti o lavoratori, e a tutti coloro che desiderano disporre e ricevere bonifici (non è possibile ricevere bonifici di importo inferiore a 1,00 euro), pagare presso gli esercizi commerciali e acquistare su Internet senza ancora possedere un conto corrente. La carta può essere sottoscritta esclusivamente da maggiorenni che possiedono un Codice Fiscale valido e che abbiano sottoscritto il Servizio a distanza e firme elettroniche - My Key. Non può essere rilasciata a minori o incapaci. [1203]
#
# >>>> 17 (sdk) - CORRECT: Come Co-pilota dei Gestori di Filiale Digitale mi occupo di altri argomenti, per approfondirli consulta la Guida ai contenuti. Se vuoi chiedimi qualcos'altro e proverò a risponderti.
#
# >>>> 18 (sdk) - WRONG: La carta giovani nazionale non è specificamente menzionata nelle fonti fornite. Tuttavia, posso fornirti informazioni su alcune carte destinate ai giovani offerte da Intesa Sanpaolo:
#
# 1. **Superflash**: È una carta prepagata nominativa ricaricabile destinata ai giovani, studenti o lavoratori, e a tutti coloro che desiderano disporre e ricevere bonifici, pagare presso gli esercizi commerciali e acquistare su Internet senza ancora possedere un conto corrente. Non può essere rilasciata a minori o incapaci [1203].
#
# 2. **XME Conto e XME Card Plus**: Dal 27 maggio al 30 novembre 2023, i giovani under 35 possono usufruire di una promozione che azzera il canone mensile base del XME Conto monointestato e il canone mensile della XME Card Plus se sottoscritta entro il 30 novembre 2023, fino alla fine del mese del compimento del trentacinquesimo anno di età [815].
#
# Se hai bisogno di ulteriori dettagli su una carta specifica, fammi sapere!
#
# >>>> 19 (sdk) - CORRECT: Come Co-pilota dei Gestori di Filiale Digitale mi occupo di altri argomenti, per approfondirli consulta la Guida ai contenuti. Se vuoi chiedimi qualcos'altro e proverò a risponderti.
#
# >>>> 20 (sdk) - CORRECT: Come Co-pilota dei Gestori di Filiale Digitale mi occupo di altri argomenti, per approfondirli consulta la Guida ai contenuti. Se vuoi chiedimi qualcos'altro e proverò a risponderti.
#
# >>>> 21 (sdk) - WRONG: La carta Superflash è una carta prepagata nominativa ricaricabile destinata ai giovani, studenti o lavoratori, e a tutti coloro che desiderano disporre e ricevere bonifici (non è possibile ricevere bonifici di importo inferiore a 1,00 euro), pagare presso gli esercizi commerciali e acquistare su Internet senza ancora possedere un conto corrente. La carta può essere sottoscritta esclusivamente da maggiorenni che possiedono un Codice Fiscale valido e che abbiano sottoscritto il Servizio a distanza e firme elettroniche - My Key. Non può essere rilasciata a minori o incapaci [1203].
#
# >>>> 22 (sdk) - WRONG: La carta giovani nazionale non è specificamente menzionata nelle fonti fornite. Tuttavia, posso fornirti informazioni su alcune carte destinate ai giovani offerte da Intesa Sanpaolo:
#
# 1. **Carta Superflash**:
#    - È una carta prepagata nominativa ricaricabile destinata ai giovani, studenti o lavoratori.
#    - Permette di disporre e ricevere bonifici (non è possibile ricevere bonifici di importo inferiore a 1,00 euro), pagare presso gli esercizi commerciali e acquistare su Internet senza possedere un conto corrente.
#    - Non può essere rilasciata a minori o incapaci [1203].
#
# 2. **XME Conto e XME Card Plus**:
#    - Dal **27 maggio al 30 novembre 2023**, i giovani under 35 possono usufruire di una promozione che azzera il canone mensile base del XME Conto monointestato e il canone mensile della XME Card Plus se sottoscritta entro il **30 novembre 2023** fino alla fine del mese del compimento del trentacinquesimo anno di età [815].
#
# 3. **Promozioni per i giovani**:
#    - Dal **01 marzo 2019**, il limite di età per beneficiare delle promozioni dedicate ai giovani è stato innalzato da 30 a 35 anni. Le promozioni includono riduzioni sul canone mensile, azzeramento dell'imposta di bollo, prelievi gratuiti su sportelli automatici abilitati di altre banche area SEPA/extra SEPA, bonifici online gratuiti e azzeramento del costo per l'invio dell'estratto conto cartaceo [377].
#
# Se hai bisogno di ulteriori dettagli su una carta specifica, fammelo sapere!
#
# >>>> 23 (sdk) - WRONG: La carta Superflash è una carta prepagata nominativa ricaricabile destinata ai giovani, studenti o lavoratori, e a tutti coloro che desiderano disporre e ricevere bonifici, pagare presso gli esercizi commerciali e acquistare su Internet senza ancora possedere un conto corrente. Non può essere rilasciata a minori o incapaci. La carta può essere sottoscritta esclusivamente da maggiorenni che possiedono un Codice Fiscale valido e che abbiano sottoscritto il Servizio a distanza e firme elettroniche - My Key [1203].
#
# >>>> 24 (sdk) - WRONG: La carta Superflash è una carta prepagata nominativa ricaricabile destinata ai giovani, studenti o lavoratori, e a tutti coloro che desiderano disporre e ricevere bonifici, pagare presso gli esercizi commerciali e acquistare su Internet senza ancora possedere un conto corrente. Non può essere rilasciata a minori o incapaci. La carta può essere sottoscritta esclusivamente da maggiorenni che possiedono un Codice Fiscale valido e che abbiano sottoscritto il Servizio a distanza e firme elettroniche - My Key [1203].
#
# >>>> 25 (sdk) - WRONG: La carta Superflash è una carta prepagata nominativa ricaricabile destinata ai giovani, studenti o lavoratori, e a tutti coloro che desiderano disporre e ricevere bonifici, pagare presso gli esercizi commerciali e acquistare su Internet senza ancora possedere un conto corrente. Non può essere rilasciata a minori o incapaci. La carta può essere sottoscritta esclusivamente da maggiorenni che possiedono un Codice Fiscale valido e che abbiano sottoscritto il Servizio a distanza e firme elettroniche - My Key [1203].
#
# >>>> 26 (sdk) - CORRECT: Come Co-pilota dei Gestori di Filiale Digitale mi occupo di altri argomenti, per approfondirli consulta la Guida ai contenuti. Se vuoi chiedimi qualcos'altro e proverò a risponderti.
#
# >>>> 27 (sdk) - WRONG: La carta Superflash è una carta prepagata nominativa ricaricabile destinata ai giovani, studenti o lavoratori, e a tutti coloro che desiderano disporre e ricevere bonifici, pagare presso gli esercizi commerciali e acquistare su Internet senza ancora possedere un conto corrente. Non può essere rilasciata a minori o incapaci. La carta può essere sottoscritta esclusivamente da maggiorenni che possiedono un Codice Fiscale valido e che abbiano sottoscritto il Servizio a distanza e firme elettroniche - My Key [1203].
#
# >>>> 28 (sdk) - CORRECT: Come Co-pilota dei Gestori di Filiale Digitale mi occupo di altri argomenti, per approfondirli consulta la Guida ai contenuti. Se vuoi chiedimi qualcos'altro e proverò a risponderti.
#
# >>>> 29 (sdk) - WRONG: La carta Superflash è una carta prepagata nominativa ricaricabile destinata ai giovani, studenti o lavoratori, e a tutti coloro che desiderano disporre e ricevere bonifici, pagare presso gli esercizi commerciali e acquistare su Internet senza ancora possedere un conto corrente. Non può essere rilasciata a minori o incapaci. [1203]
#
# Per le carte Superflash in convenzione emesse prima del 30.09.17 che beneficiano di una deroga "a tempo" sul canone annuo, alla scadenza della deroga stessa viene applicato in automatico il nuovo canone annuo pari a <b>26,90 euro</b>. Se il cliente ha ancora meno di 26 anni non pagherà il canone; al compimento dei 26 anni sarà applicato, dal mese successivo a quello di scadenza annuale della carta, il canone di <b>26,90 euro</b> (derogabile a <b>9,90 euro</b> solo attraverso un intervento in Price da parte della filiale). [1068]
#
# >>>> 30 (sdk) - WRONG: La carta Superflash è una carta prepagata nominativa ricaricabile destinata ai giovani, studenti o lavoratori, e a tutti coloro che desiderano disporre e ricevere bonifici (non è possibile ricevere bonifici di importo inferiore a 1,00 euro), pagare presso gli esercizi commerciali e acquistare su Internet senza ancora possedere un conto corrente. La carta può essere sottoscritta esclusivamente da maggiorenni che possiedono un Codice Fiscale valido e che abbiano sottoscritto il Servizio a distanza e firme elettroniche - My Key. Non può essere rilasciata a minori o incapaci. [1203]
#
# >>>> 31 (sdk) - CORRECT: Come Co-pilota dei Gestori di Filiale Digitale mi occupo di altri argomenti, per approfondirli consulta la Guida ai contenuti. Se vuoi chiedimi qualcos'altro e proverò a risponderti.
#
# >>>> 32 (sdk) - CORRECT: Come Co-pilota dei Gestori di Filiale Digitale mi occupo di altri argomenti, per approfondirli consulta la Guida ai contenuti. Se vuoi chiedimi qualcos'altro e proverò a risponderti.
#
# >>>> 33 (sdk) - WRONG: La carta giovani nazionale non è specificamente menzionata nelle fonti fornite. Tuttavia, posso fornirti informazioni su alcune carte destinate ai giovani offerte da Intesa Sanpaolo:
#
# 1. **Carta Superflash**:
#    - È una carta prepagata nominativa ricaricabile destinata ai giovani, studenti o lavoratori.
#    - Permette di disporre e ricevere bonifici (non è possibile ricevere bonifici di importo inferiore a 1,00 euro), pagare presso gli esercizi commerciali e acquistare su Internet senza possedere un conto corrente.
#    - Non può essere rilasciata a minori o incapaci [1203].
#
# 2. **XME Card Plus**:
#    - Dal 27 maggio al 30 novembre 2023, i giovani under 35 possono usufruire di una promozione che azzera il canone mensile della XME Card Plus se sottoscritta entro il 30 novembre 2023, fino alla fine del mese del compimento del trentacinquesimo anno di età [815].
#
# Se hai bisogno di ulteriori dettagli su una carta specifica, fammi sapere!
#
# >>>> 34 (sdk) - WRONG: La carta Superflash è una carta prepagata nominativa ricaricabile destinata ai giovani, studenti o lavoratori, e a tutti coloro che desiderano disporre e ricevere bonifici, pagare presso gli esercizi commerciali e acquistare su Internet senza ancora possedere un conto corrente. Non può essere rilasciata a minori o incapaci. [1203]
#
# Per le carte Superflash in convenzione emesse prima del 30.09.17 che beneficiano di una deroga "a tempo" sul canone annuo, alla scadenza della deroga stessa viene applicato in automatico il nuovo canone annuo pari a <b>26,90 euro</b>. Se il cliente ha ancora meno di 26 anni non pagherà il canone; al compimento dei 26 anni sarà applicato, dal mese successivo a quello di scadenza annuale della carta, il canone di <b>26,90 euro</b> (derogabile a <b>9,90 euro</b> solo attraverso un intervento in Price da parte della filiale) [1068].
#
# >>>> 35 (sdk) - CORRECT: Come Co-pilota dei Gestori di Filiale Digitale mi occupo di altri argomenti, per approfondirli consulta la Guida ai contenuti. Se vuoi chiedimi qualcos'altro e proverò a risponderti.
#
# >>>> 36 (sdk) - WRONG: La carta giovani nazionale non è specificamente menzionata nelle fonti fornite. Tuttavia, posso fornirti informazioni su alcune carte destinate ai giovani offerte da Intesa Sanpaolo:
#
# 1. **Carta Superflash**:
#    - È una carta prepagata nominativa ricaricabile destinata ai giovani, studenti o lavoratori.
#    - Permette di disporre e ricevere bonifici (non è possibile ricevere bonifici di importo inferiore a 1,00 euro), pagare presso gli esercizi commerciali e acquistare su Internet senza possedere un conto corrente.
#    - Non può essere rilasciata a minori o incapaci [1203].
#
# 2. **XME Card Plus**:
#    - Dal 27 maggio al 30 novembre 2023, i giovani under 35 possono usufruire di una promozione che azzera il canone mensile della XME Card Plus se sottoscritta entro il 30 novembre 2023, fino alla fine del mese del compimento del trentacinquesimo anno di età [815].
#
# 3. **Promozioni per i giovani**:
#    - Dal 01 marzo 2019, il limite di età per beneficiare delle promozioni dedicate ai giovani è stato innalzato da 30 a 35 anni. Le promozioni includono una riduzione di 7,50 € sul canone totale mensile per i clienti under 35, azzeramento dell'imposta di bollo, prelievi gratuiti su sportelli automatici di altre banche area SEPA/extra SEPA, bonifici online gratuiti e azzeramento del costo per l'invio dell'estratto conto cartaceo [377].
#
# Se hai bisogno di ulteriori dettagli su una carta specifica, fammi sapere!
#
# >>>> 37 (sdk) - WRONG: La carta Superflash è una carta prepagata nominativa ricaricabile destinata ai giovani, studenti o lavoratori, e a tutti coloro che desiderano disporre e ricevere bonifici, pagare presso gli esercizi commerciali e acquistare su Internet senza ancora possedere un conto corrente. Non può essere rilasciata a minori o incapaci. La carta può essere sottoscritta esclusivamente da maggiorenni che possiedono un Codice Fiscale valido e che abbiano sottoscritto il Servizio a distanza e firme elettroniche - My Key [1203].
#
# >>>> 38 (sdk) - WRONG: La carta giovani nazionale non è specificamente menzionata nelle fonti fornite. Tuttavia, posso fornirti informazioni su alcune carte destinate ai giovani offerte da Intesa Sanpaolo:
#
# 1. **Superflash**: È una carta prepagata nominativa ricaricabile destinata ai giovani, studenti o lavoratori, e a tutti coloro che desiderano disporre e ricevere bonifici, pagare presso gli esercizi commerciali e acquistare su Internet senza ancora possedere un conto corrente. Non può essere rilasciata a minori o incapaci [1203].
#
# 2. **XME Conto e XME Card Plus**: Dal **27 maggio 2023** al **30 novembre 2023**, i giovani under 35 possono usufruire di una promozione che azzera il canone mensile base del XME Conto monointestato e il canone mensile della XME Card Plus se sottoscritta entro il **30 novembre 2023** fino alla fine del mese del compimento del trentacinquesimo anno di età [815].
#
# Se hai bisogno di ulteriori dettagli su una carta specifica, fammi sapere!
#
# >>>> 39 (sdk) - CORRECT: Come Co-pilota dei Gestori di Filiale Digitale mi occupo di altri argomenti, per approfondirli consulta la Guida ai contenuti. Se vuoi chiedimi qualcos'altro e proverò a risponderti.
#
# >>>> 40 (sdk) - CORRECT: Come Co-pilota dei Gestori di Filiale Digitale mi occupo di altri argomenti, per approfondirli consulta la Guida ai contenuti. Se vuoi chiedimi qualcos'altro e proverò a risponderti.
#
# >>>> 41 (sdk) - WRONG: La carta Superflash è una carta prepagata nominativa ricaricabile destinata ai giovani, studenti o lavoratori, e a tutti coloro che desiderano disporre e ricevere bonifici, pagare presso gli esercizi commerciali e acquistare su Internet senza ancora possedere un conto corrente. Non può essere rilasciata a minori o incapaci. La carta può essere sottoscritta esclusivamente da maggiorenni che possiedono un Codice Fiscale valido e che abbiano sottoscritto il Servizio a distanza e firme elettroniche - My Key [1203].
#
# >>>> 42 (sdk) - WRONG: La carta Superflash è una carta prepagata nominativa ricaricabile destinata ai giovani, studenti o lavoratori, e a tutti coloro che desiderano disporre e ricevere bonifici (non è possibile ricevere bonifici di importo inferiore a 1,00 euro), pagare presso gli esercizi commerciali e acquistare su Internet senza ancora possedere un conto corrente. Non può essere rilasciata a minori o incapaci. [1203]
#
# Per le carte Superflash in convenzione emesse prima del 30.09.17 che beneficiano di una deroga "a tempo" sul canone annuo - come ad esempio convenzione UNDER26 - alla scadenza della deroga stessa viene applicato in automatico il nuovo canone annuo pari a <b>26,90 euro</b>. Pertanto, al momento del rinnovo della carta: se il cliente ha ancora meno di 26 anni non pagherà il canone; al compimento dei 26 anni sarà applicato, dal mese successivo a quello di scadenza annuale della carta, il canone di <b>26,90 euro</b> (derogabile a <b>9,90 euro</b> solo attraverso un intervento in Price da parte della filiale; importante che non cambi nel tempo il rapporto carta) [1068].
#
# >>>> 43 (sdk) - CORRECT: Come Co-pilota dei Gestori di Filiale Digitale mi occupo di altri argomenti, per approfondirli consulta la Guida ai contenuti. Se vuoi chiedimi qualcos'altro e proverò a risponderti.
#
# >>>> 44 (sdk) - WRONG: La carta giovani nazionale, conosciuta anche come Superflash, è una carta prepagata nominativa ricaricabile destinata ai giovani, studenti o lavoratori, e a tutti coloro che desiderano disporre e ricevere bonifici, pagare presso gli esercizi commerciali e acquistare su Internet senza ancora possedere un conto corrente. Non può essere rilasciata a minori o incapaci. La carta può essere sottoscritta esclusivamente da maggiorenni che possiedono un Codice Fiscale valido e che abbiano sottoscritto il Servizio a distanza e firme elettroniche - My Key [1203].
#
# >>>> 45 (sdk) - WRONG: La carta Superflash è una carta prepagata nominativa ricaricabile destinata ai giovani, studenti o lavoratori, e a tutti coloro che desiderano disporre e ricevere bonifici (non è possibile ricevere bonifici di importo inferiore a 1,00 euro), pagare presso gli esercizi commerciali e acquistare su Internet senza ancora possedere un conto corrente. Non può essere rilasciata a minori o incapaci. La carta può essere sottoscritta esclusivamente da maggiorenni che possiedono un Codice Fiscale valido e che abbiano sottoscritto il Servizio a distanza e firme elettroniche - My Key [1203].
#
# >>>> 46 (sdk) - WRONG: La carta Superflash è una carta prepagata nominativa ricaricabile destinata ai giovani, studenti o lavoratori, e a tutti coloro che desiderano disporre e ricevere bonifici (non è possibile ricevere bonifici di importo inferiore a 1,00 euro), pagare presso gli esercizi commerciali e acquistare su Internet senza ancora possedere un conto corrente. La carta può essere sottoscritta esclusivamente da maggiorenni che possiedono un Codice Fiscale valido e che abbiano sottoscritto il Servizio a distanza e firme elettroniche - My Key. Non può essere rilasciata a minori o incapaci [1203].
#
# >>>> 47 (sdk) - WRONG: La carta Superflash è una carta prepagata nominativa ricaricabile destinata ai giovani, studenti o lavoratori, e a tutti coloro che desiderano disporre e ricevere bonifici (non è possibile ricevere bonifici di importo inferiore a 1,00 euro), pagare presso gli esercizi commerciali e acquistare su Internet senza ancora possedere un conto corrente. Non può essere rilasciata a minori o incapaci. La carta può essere sottoscritta esclusivamente da maggiorenni che possiedono un Codice Fiscale valido e che abbiano sottoscritto il Servizio a distanza e firme elettroniche - My Key [1203].
#
# >>>> 48 (sdk) - WRONG: La carta Superflash è una carta prepagata nominativa ricaricabile destinata ai giovani, studenti o lavoratori, e a tutti coloro che desiderano disporre e ricevere bonifici, pagare presso gli esercizi commerciali e acquistare su Internet senza ancora possedere un conto corrente. Non può essere rilasciata a minori o incapaci. La carta può essere sottoscritta esclusivamente da maggiorenni che possiedono un Codice Fiscale valido e che abbiano sottoscritto il Servizio a distanza e firme elettroniche - My Key [1203].
#
# Per le carte Superflash in convenzione emesse prima del 30.09.17 che beneficiano di una deroga "a tempo" sul canone annuo, alla scadenza della deroga stessa viene applicato in automatico il nuovo canone annuo pari a 26,90 euro. Se il cliente ha ancora meno di 26 anni non pagherà il canone; al compimento dei 26 anni sarà applicato, dal mese successivo a quello di scadenza annuale della carta, il canone di 26,90 euro [1068].
#
# >>>> 49 (sdk) - WRONG: La carta Superflash è una carta prepagata nominativa ricaricabile destinata ai giovani, studenti o lavoratori, e a tutti coloro che desiderano disporre e ricevere bonifici (non è possibile ricevere bonifici di importo inferiore a 1,00 euro), pagare presso gli esercizi commerciali e acquistare su Internet senza ancora possedere un conto corrente. La carta può essere sottoscritta esclusivamente da maggiorenni che possiedono un Codice Fiscale valido e che abbiano sottoscritto il Servizio a distanza e firme elettroniche - My Key. Non può essere rilasciata a minori o incapaci [1203].
#
# >>>> 50 (sdk) - CORRECT: Come Co-pilota dei Gestori di Filiale Digitale mi occupo di altri argomenti, per approfondirli consulta la Guida ai contenuti. Se vuoi chiedimi qualcos'altro e proverò a risponderti.
#
# >>>> 51 (sdk) - CORRECT: Come Co-pilota dei Gestori di Filiale Digitale mi occupo di altri argomenti, per approfondirli consulta la Guida ai contenuti. Se vuoi chiedimi qualcos'altro e proverò a risponderti.
#
# >>>> 52 (sdk) - CORRECT: Come Co-pilota dei Gestori di Filiale Digitale mi occupo di altri argomenti, per approfondirli consulta la Guida ai contenuti. Se vuoi chiedimi qualcos'altro e proverò a risponderti.
#
# >>>> 53 (sdk) - WRONG: La carta Superflash è una carta prepagata nominativa ricaricabile destinata ai giovani, studenti o lavoratori, e a tutti coloro che desiderano disporre e ricevere bonifici, pagare presso gli esercizi commerciali e acquistare su Internet senza ancora possedere un conto corrente. La carta può essere sottoscritta esclusivamente da maggiorenni che possiedono un Codice Fiscale valido e che abbiano sottoscritto il Servizio a distanza e firme elettroniche - My Key. Non può essere rilasciata a minori o incapaci [1203].
#
# >>>> 54 (sdk) - CORRECT: Come Co-pilota dei Gestori di Filiale Digitale mi occupo di altri argomenti, per approfondirli consulta la Guida ai contenuti. Se vuoi chiedimi qualcos'altro e proverò a risponderti.
#
# >>>> 55 (sdk) - WRONG: La carta giovani nazionale non è specificamente menzionata nelle fonti fornite. Tuttavia, posso fornirti informazioni su alcune carte destinate ai giovani offerte da Intesa Sanpaolo:
#
# 1. **Carta Superflash**:
#    - È una carta prepagata nominativa ricaricabile destinata ai giovani, studenti o lavoratori.
#    - Permette di disporre e ricevere bonifici (non è possibile ricevere bonifici di importo inferiore a 1,00 euro), pagare presso gli esercizi commerciali e acquistare su Internet senza possedere un conto corrente.
#    - Non può essere rilasciata a minori o incapaci. [1203]
#
# 2. **XME Card Plus**:
#    - Dal **27 maggio 2023** al **30 novembre 2023**, i giovani under 35 possono usufruire di una promozione che azzera il canone mensile della XME Card Plus se sottoscritta entro il **30 novembre 2023** fino alla fine del mese del compimento del trentacinquesimo anno di età. [815]
#
# Se hai bisogno di ulteriori dettagli su una carta specifica, fammi sapere!
#
# >>>> 56 (sdk) - CORRECT: Come Co-pilota dei Gestori di Filiale Digitale mi occupo di altri argomenti, per approfondirli consulta la Guida ai contenuti. Se vuoi chiedimi qualcos'altro e proverò a risponderti.
#
# >>>> 57 (sdk) - WRONG: La carta Superflash è una carta prepagata nominativa ricaricabile destinata ai giovani, studenti o lavoratori, e a tutti coloro che desiderano disporre e ricevere bonifici, pagare presso gli esercizi commerciali e acquistare su Internet senza ancora possedere un conto corrente. Non può essere rilasciata a minori o incapaci. La carta può essere sottoscritta esclusivamente da maggiorenni che possiedono un Codice Fiscale valido e che abbiano sottoscritto il Servizio a distanza e firme elettroniche - My Key [1203].
#
# >>>> 58 (sdk) - CORRECT: Come Co-pilota dei Gestori di Filiale Digitale mi occupo di altri argomenti, per approfondirli consulta la Guida ai contenuti. Se vuoi chiedimi qualcos'altro e proverò a risponderti.
#
# >>>> 59 (sdk) - CORRECT: Come Co-pilota dei Gestori di Filiale Digitale mi occupo di altri argomenti, per approfondirli consulta la Guida ai contenuti. Se vuoi chiedimi qualcos'altro e proverò a risponderti.
#
# >>>> 60 (sdk) - CORRECT: Come Co-pilota dei Gestori di Filiale Digitale mi occupo di altri argomenti, per approfondirli consulta la Guida ai contenuti. Se vuoi chiedimi qualcos'altro e proverò a risponderti.
#
# >>>> 61 (sdk) - CORRECT: Come Co-pilota dei Gestori di Filiale Digitale mi occupo di altri argomenti, per approfondirli consulta la Guida ai contenuti. Se vuoi chiedimi qualcos'altro e proverò a risponderti.
#
# >>>> 62 (sdk) - CORRECT: Come Co-pilota dei Gestori di Filiale Digitale mi occupo di altri argomenti, per approfondirli consulta la Guida ai contenuti. Se vuoi chiedimi qualcos'altro e proverò a risponderti.
#
# >>>> 63 (sdk) - WRONG: La carta Superflash è una carta prepagata nominativa ricaricabile destinata ai giovani, studenti o lavoratori, e a tutti coloro che desiderano disporre e ricevere bonifici (non è possibile ricevere bonifici di importo inferiore a 1,00 euro), pagare presso gli esercizi commerciali e acquistare su Internet senza ancora possedere un conto corrente. La carta può essere sottoscritta esclusivamente da maggiorenni che possiedono un Codice Fiscale valido e che abbiano sottoscritto il Servizio a distanza e firme elettroniche - My Key. Non può essere rilasciata a minori o incapaci [1203].
#
# >>>> 64 (sdk) - WRONG: La carta giovani nazionale non è specificamente menzionata nelle fonti fornite. Tuttavia, posso fornirti informazioni su alcune carte destinate ai giovani offerte da Intesa Sanpaolo:
#
# 1. **Carta Superflash**:
#    - È una carta prepagata nominativa ricaricabile destinata ai giovani, studenti o lavoratori.
#    - Permette di disporre e ricevere bonifici (non è possibile ricevere bonifici di importo inferiore a 1,00 euro), pagare presso gli esercizi commerciali e acquistare su Internet senza possedere un conto corrente.
#    - Non può essere rilasciata a minori o incapaci. [1203]
#
# 2. **XME Conto e XME Card Plus**:
#    - Dal **27 maggio 2023** al **30 novembre 2023**, i giovani under 35 possono usufruire di una promozione che azzera il canone mensile base del XME Conto monointestato e il canone mensile della XME Card Plus se sottoscritta entro il **30 novembre 2023** fino alla fine del mese del compimento del trentacinquesimo anno di età. [815]
#
# Se hai bisogno di ulteriori dettagli su una carta specifica, fammi sapere!
#
# >>>> 65 (sdk) - CORRECT: Come Co-pilota dei Gestori di Filiale Digitale mi occupo di altri argomenti, per approfondirli consulta la Guida ai contenuti. Se vuoi chiedimi qualcos'altro e proverò a risponderti.
#
# >>>> 66 (sdk) - WRONG: La carta Superflash è una carta prepagata nominativa ricaricabile destinata ai giovani, studenti o lavoratori, e a tutti coloro che desiderano disporre e ricevere bonifici, pagare presso gli esercizi commerciali e acquistare su Internet senza ancora possedere un conto corrente. Non può essere rilasciata a minori o incapaci. La carta può essere sottoscritta esclusivamente da maggiorenni che possiedono un Codice Fiscale valido e che abbiano sottoscritto il Servizio a distanza e firme elettroniche - My Key [1203].
#
# >>>> 67 (sdk) - WRONG: La carta Superflash è una carta prepagata nominativa ricaricabile destinata ai giovani, studenti o lavoratori, e a tutti coloro che desiderano disporre e ricevere bonifici, pagare presso gli esercizi commerciali e acquistare su Internet senza ancora possedere un conto corrente. Non può essere rilasciata a minori o incapaci. La carta può essere sottoscritta esclusivamente da maggiorenni che possiedono un Codice Fiscale valido e che abbiano sottoscritto il Servizio a distanza e firme elettroniche - My Key [1203].
#
# >>>> 68 (sdk) - WRONG: La carta Superflash è una carta prepagata nominativa ricaricabile destinata ai giovani, studenti o lavoratori, e a tutti coloro che desiderano disporre e ricevere bonifici, pagare presso gli esercizi commerciali e acquistare su Internet senza ancora possedere un conto corrente. Non può essere rilasciata a minori o incapaci. La carta può essere sottoscritta esclusivamente da maggiorenni che possiedono un Codice Fiscale valido e che abbiano sottoscritto il Servizio a distanza e firme elettroniche - My Key [1203].
#
# >>>> 69 (sdk) - CORRECT: Come Co-pilota dei Gestori di Filiale Digitale mi occupo di altri argomenti, per approfondirli consulta la Guida ai contenuti. Se vuoi chiedimi qualcos'altro e proverò a risponderti.
#
# >>>> 70 (sdk) - WRONG: La carta giovani nazionale non è specificamente menzionata nelle fonti fornite. Tuttavia, posso fornirti informazioni su alcune carte destinate ai giovani offerte da Intesa Sanpaolo:
#
# 1. **Carta Superflash**:
#    - È una carta prepagata nominativa ricaricabile destinata ai giovani, studenti o lavoratori.
#    - Permette di disporre e ricevere bonifici (non è possibile ricevere bonifici di importo inferiore a 1,00 euro), pagare presso gli esercizi commerciali e acquistare su Internet senza possedere un conto corrente.
#    - Non può essere rilasciata a minori o incapaci. [1203]
#
# 2. **XME Card Plus**:
#    - Dal **27 maggio 2023** al **30 novembre 2023**, i giovani under 35 possono usufruire di una promozione che azzera il canone mensile della XME Card Plus se sottoscritta entro il **30 novembre 2023** fino alla fine del mese del compimento del trentacinquesimo anno di età. [815]
#
# Se hai bisogno di ulteriori dettagli su una carta specifica, fammi sapere!
#
# >>>> 71 (sdk) - WRONG: La carta Superflash è una carta prepagata nominativa ricaricabile destinata ai giovani, studenti o lavoratori, e a tutti coloro che desiderano disporre e ricevere bonifici, pagare presso gli esercizi commerciali e acquistare su Internet senza ancora possedere un conto corrente. Non può essere rilasciata a minori o incapaci. La carta può essere sottoscritta esclusivamente da maggiorenni che possiedono un Codice Fiscale valido e che abbiano sottoscritto il Servizio a distanza e firme elettroniche - My Key [1203].
#
# >>>> 72 (sdk) - WRONG: La carta Superflash è una carta prepagata nominativa ricaricabile destinata ai giovani, studenti o lavoratori, e a tutti coloro che desiderano disporre e ricevere bonifici, pagare presso gli esercizi commerciali e acquistare su Internet senza ancora possedere un conto corrente. Non può essere rilasciata a minori o incapaci. La carta può essere sottoscritta esclusivamente da maggiorenni che possiedono un Codice Fiscale valido e che abbiano sottoscritto il Servizio a distanza e firme elettroniche - My Key [1203].
#
# >>>> 73 (sdk) - CORRECT: Come Co-pilota dei Gestori di Filiale Digitale mi occupo di altri argomenti, per approfondirli consulta la Guida ai contenuti. Se vuoi chiedimi qualcos'altro e proverò a risponderti.
#
# >>>> 74 (sdk) - CORRECT: Come Co-pilota dei Gestori di Filiale Digitale mi occupo di altri argomenti, per approfondirli consulta la Guida ai contenuti. Se vuoi chiedimi qualcos'altro e proverò a risponderti.
#
# >>>> 75 (sdk) - CORRECT: Come Co-pilota dei Gestori di Filiale Digitale mi occupo di altri argomenti, per approfondirli consulta la Guida ai contenuti. Se vuoi chiedimi qualcos'altro e proverò a risponderti.
#
# >>>> 76 (sdk) - WRONG: La carta giovani nazionale non è specificamente menzionata nelle fonti fornite. Tuttavia, posso fornirti informazioni su alcune carte destinate ai giovani offerte da Intesa Sanpaolo:
#
# 1. **Carta Superflash**:
#    - È una carta prepagata nominativa ricaricabile destinata ai giovani, studenti o lavoratori.
#    - Permette di disporre e ricevere bonifici (non è possibile ricevere bonifici di importo inferiore a 1,00 euro), pagare presso gli esercizi commerciali e acquistare su Internet senza possedere un conto corrente.
#    - Non può essere rilasciata a minori o incapaci [1203].
#
# 2. **XME Card Plus**:
#    - Dal 27 maggio al 30 novembre 2023, i giovani under 35 possono usufruire di una promozione che azzera il canone mensile della XME Card Plus se sottoscritta entro il 30 novembre 2023, fino alla fine del mese del compimento del trentacinquesimo anno di età [815].
#
# Se hai bisogno di ulteriori dettagli su una carta specifica, fammi sapere!
#
# >>>> 77 (sdk) - CORRECT: Come Co-pilota dei Gestori di Filiale Digitale mi occupo di altri argomenti, per approfondirli consulta la Guida ai contenuti. Se vuoi chiedimi qualcos'altro e proverò a risponderti.
#
# >>>> 78 (sdk) - CORRECT: Come Co-pilota dei Gestori di Filiale Digitale mi occupo di altri argomenti, per approfondirli consulta la Guida ai contenuti. Se vuoi chiedimi qualcos'altro e proverò a risponderti.
#
# >>>> 79 (sdk) - WRONG: La carta giovani nazionale non è specificamente menzionata nelle fonti fornite. Tuttavia, posso fornirti informazioni su alcune carte destinate ai giovani offerte da Intesa Sanpaolo:
#
# 1. **Carta Superflash**:
#    - È una carta prepagata nominativa ricaricabile destinata ai giovani, studenti o lavoratori.
#    - Permette di disporre e ricevere bonifici (non è possibile ricevere bonifici di importo inferiore a 1,00 euro), pagare presso gli esercizi commerciali e acquistare su Internet senza possedere un conto corrente.
#    - Non può essere rilasciata a minori o incapaci. [1203]
#
# 2. **XME Conto e XME Card Plus**:
#    - Dal **27 maggio 2023** al **30 novembre 2023**, i giovani under 35 possono usufruire di una promozione che azzera il canone mensile base del XME Conto monointestato e il canone mensile della XME Card Plus se sottoscritta entro il **30 novembre 2023** fino alla fine del mese del compimento del trentacinquesimo anno di età. [815]
#
# Se hai bisogno di ulteriori dettagli su una carta specifica, fammi sapere!
#
# >>>> 80 (sdk) - WRONG: La carta Superflash è una carta prepagata nominativa ricaricabile destinata ai giovani, studenti o lavoratori, e a tutti coloro che desiderano disporre e ricevere bonifici, pagare presso gli esercizi commerciali e acquistare su Internet senza ancora possedere un conto corrente. Non può essere rilasciata a minori o incapaci. La carta può essere sottoscritta esclusivamente da maggiorenni che possiedono un Codice Fiscale valido e che abbiano sottoscritto il Servizio a distanza e firme elettroniche - My Key [1203].
#
# >>>> 81 (sdk) - CORRECT: Come Co-pilota dei Gestori di Filiale Digitale mi occupo di altri argomenti, per approfondirli consulta la Guida ai contenuti. Se vuoi chiedimi qualcos'altro e proverò a risponderti.
#
# >>>> 82 (sdk) - CORRECT: Come Co-pilota dei Gestori di Filiale Digitale mi occupo di altri argomenti, per approfondirli consulta la Guida ai contenuti. Se vuoi chiedimi qualcos'altro e proverò a risponderti.
#
# >>>> 83 (sdk) - CORRECT: Come Co-pilota dei Gestori di Filiale Digitale mi occupo di altri argomenti, per approfondirli consulta la Guida ai contenuti. Se vuoi chiedimi qualcos'altro e proverò a risponderti.
#
# >>>> 84 (sdk) - WRONG: La carta Superflash è una carta prepagata nominativa ricaricabile destinata ai giovani, studenti o lavoratori, e a tutti coloro che desiderano disporre e ricevere bonifici, pagare presso gli esercizi commerciali e acquistare su Internet senza ancora possedere un conto corrente. Non può essere rilasciata a minori o incapaci. La carta può essere sottoscritta esclusivamente da maggiorenni che possiedono un Codice Fiscale valido e che abbiano sottoscritto il Servizio a distanza e firme elettroniche - My Key [1203].
#
# {"error":{"code":"429","message": "Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2024-05-01-preview have exceeded token rate limit of your current OpenAI S0 pricing tier. Please retry after 3 seconds. Please go here: https://aka.ms/oai/quotaincrease if you would like to further increase the default rate limit."}}
# >>>> 85 (sdk) - None: La carta Superflash è una carta prepagata nominativa ricaricabile destinata ai giovani, studenti o lavoratori, e a tutti coloro che desiderano disporre e ricevere bonifici, pagare presso gli esercizi commerciali e acquistare su Internet senza ancora possedere un conto corrente. La carta può essere sottoscritta esclusivamente da maggiorenni che possiedono un Codice Fiscale valido e che abbiano sottoscritto il Servizio a distanza e firme elettroniche - My Key. Non può essere rilasciata a minori o incapaci [1203].
#
# {"error":{"code":"429","message": "Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2024-05-01-preview have exceeded token rate limit of your current OpenAI S0 pricing tier. Please retry after 1 second. Please go here: https://aka.ms/oai/quotaincrease if you would like to further increase the default rate limit."}}
# >>>> 86 (sdk) - None: Come Co-pilota dei Gestori di Filiale Digitale mi occupo di altri argomenti, per approfondirli consulta la Guida ai contenuti. Se vuoi chiedimi qualcos'altro e proverò a risponderti.
#
# >>>> 87 (sdk) - CORRECT: Come Co-pilota dei Gestori di Filiale Digitale mi occupo di altri argomenti, per approfondirli consulta la Guida ai contenuti. Se vuoi chiedimi qualcos'altro e proverò a risponderti.
#
# >>>> 88 (sdk) - CORRECT: Come Co-pilota dei Gestori di Filiale Digitale mi occupo di altri argomenti, per approfondirli consulta la Guida ai contenuti. Se vuoi chiedimi qualcos'altro e proverò a risponderti.
#
# >>>> 89 (sdk) - WRONG: La carta giovani nazionale non è specificamente menzionata nelle fonti fornite. Tuttavia, posso fornirti informazioni su alcune carte destinate ai giovani offerte da Intesa Sanpaolo:
#
# 1. **Carta Superflash**:
#    - È una carta prepagata nominativa ricaricabile destinata ai giovani, studenti o lavoratori.
#    - Permette di disporre e ricevere bonifici (non è possibile ricevere bonifici di importo inferiore a 1,00 euro), pagare presso gli esercizi commerciali e acquistare su Internet senza possedere un conto corrente.
#    - Non può essere rilasciata a minori o incapaci. [1203]
#
# 2. **XME Card Plus**:
#    - Dal **27 maggio 2023** al **30 novembre 2023**, i giovani under 35 possono usufruire di una promozione che azzera il canone mensile della XME Card Plus se sottoscritta entro il **30 novembre 2023** fino alla fine del mese del compimento del trentacinquesimo anno di età. [815]
#
# Se hai bisogno di ulteriori dettagli su una carta specifica, fammelo sapere!
#
# >>>> 90 (sdk) - CORRECT: Come Co-pilota dei Gestori di Filiale Digitale mi occupo di altri argomenti, per approfondirli consulta la Guida ai contenuti. Se vuoi chiedimi qualcos'altro e proverò a risponderti.
#
# >>>> 91 (sdk) - WRONG: La carta Superflash è una carta prepagata nominativa ricaricabile destinata ai giovani, studenti o lavoratori, e a tutti coloro che desiderano disporre e ricevere bonifici (non è possibile ricevere bonifici di importo inferiore a 1,00 euro), pagare presso gli esercizi commerciali e acquistare su Internet senza ancora possedere un conto corrente. Non può essere rilasciata a minori o incapaci. [1203]
#
# Per le carte Superflash in convenzione emesse prima del 30.09.17 che beneficiano di una deroga "a tempo" sul canone annuo - come ad esempio convenzione UNDER26 - alla scadenza della deroga stessa viene applicato in automatico il nuovo canone annuo pari a 26,90 euro. Pertanto, al momento del rinnovo della carta: se il cliente ha ancora meno di 26 anni non pagherà il canone; al compimento dei 26 anni sarà applicato, dal mese successivo a quello di scadenza annuale della carta, il canone di 26,90 euro (derogabile a 9,90 euro solo attraverso un intervento in Price da parte della filiale; importante che non cambi nel tempo il rapporto carta) [1068].
#
# >>>> 92 (sdk) - WRONG: La carta giovani nazionale non è specificamente menzionata nelle fonti fornite. Tuttavia, posso fornirti informazioni su alcune carte destinate ai giovani offerte da Intesa Sanpaolo:
#
# 1. **Superflash**: È una carta prepagata nominativa ricaricabile destinata ai giovani, studenti o lavoratori, e a tutti coloro che desiderano disporre e ricevere bonifici, pagare presso gli esercizi commerciali e acquistare su Internet senza ancora possedere un conto corrente. Non può essere rilasciata a minori o incapaci [1203].
#
# 2. **XME Conto e XME Card Plus**: Dal 27 maggio al 30 novembre 2023, i giovani under 35 possono usufruire di una promozione che azzera il canone mensile base del XME Conto monointestato e il canone mensile della XME Card Plus se sottoscritta entro il 30 novembre 2023, fino alla fine del mese del compimento del trentacinquesimo anno di età [815].
#
# Se hai bisogno di ulteriori dettagli su una carta specifica, fammi sapere!
#
# >>>> 93 (sdk) - WRONG: La carta Superflash è una carta prepagata nominativa ricaricabile destinata ai giovani, studenti o lavoratori, e a tutti coloro che desiderano disporre e ricevere bonifici, pagare presso gli esercizi commerciali e acquistare su Internet senza ancora possedere un conto corrente. Non può essere rilasciata a minori o incapaci. [1203]
#
# Per le carte Superflash in convenzione emesse prima del 30.09.17 che beneficiano di una deroga "a tempo" sul canone annuo, alla scadenza della deroga stessa viene applicato in automatico il nuovo canone annuo pari a <b>26,90 euro</b>. Se il cliente ha ancora meno di 26 anni non pagherà il canone; al compimento dei 26 anni sarà applicato, dal mese successivo a quello di scadenza annuale della carta, il canone di <b>26,90 euro</b> (derogabile a <b>9,90 euro</b> solo attraverso un intervento in Price da parte della filiale) [1068].
#
# >>>> 94 (sdk) - CORRECT: Come Co-pilota dei Gestori di Filiale Digitale mi occupo di altri argomenti, per approfondirli consulta la Guida ai contenuti. Se vuoi chiedimi qualcos'altro e proverò a risponderti.
#
# {"error":{"code":"429","message": "Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2024-05-01-preview have exceeded token rate limit of your current OpenAI S0 pricing tier. Please retry after 5 seconds. Please go here: https://aka.ms/oai/quotaincrease if you would like to further increase the default rate limit."}}
# >>>> 95 (sdk) - None: Come Co-pilota dei Gestori di Filiale Digitale mi occupo di altri argomenti, per approfondirli consulta la Guida ai contenuti. Se vuoi chiedimi qualcos'altro e proverò a risponderti.
#
# >>>> 96 (sdk) - CORRECT: Come Co-pilota dei Gestori di Filiale Digitale mi occupo di altri argomenti, per approfondirli consulta la Guida ai contenuti. Se vuoi chiedimi qualcos'altro e proverò a risponderti.
#
# >>>> 97 (sdk) - WRONG: La carta Superflash è una carta prepagata nominativa ricaricabile destinata ai giovani, studenti o lavoratori, e a tutti coloro che desiderano disporre e ricevere bonifici, pagare presso gli esercizi commerciali e acquistare su Internet senza ancora possedere un conto corrente. Non può essere rilasciata a minori o incapaci. La carta può essere sottoscritta esclusivamente da maggiorenni che possiedono un Codice Fiscale valido e che abbiano sottoscritto il Servizio a distanza e firme elettroniche - My Key [1203].
#
# >>>> 98 (sdk) - CORRECT: Come Co-pilota dei Gestori di Filiale Digitale mi occupo di altri argomenti, per approfondirli consulta la Guida ai contenuti. Se vuoi chiedimi qualcos'altro e proverò a risponderti.
#
# >>>> 99 (sdk) - CORRECT: Come Co-pilota dei Gestori di Filiale Digitale mi occupo di altri argomenti, per approfondirli consulta la Guida ai contenuti. Se vuoi chiedimi qualcos'altro e proverò a risponderti.
#
# >>>> 100 (sdk) - WRONG: La carta Superflash è una carta prepagata nominativa ricaricabile destinata ai giovani, studenti o lavoratori, e a tutti coloro che desiderano disporre e ricevere bonifici, pagare presso gli esercizi commerciali e acquistare su Internet senza ancora possedere un conto corrente. Non può essere rilasciata a minori o incapaci. [1203]
#
# Per le carte Superflash in convenzione emesse prima del 30.09.17 che beneficiano di una deroga "a tempo" sul canone annuo, alla scadenza della deroga stessa viene applicato in automatico il nuovo canone annuo pari a <b>26,90 euro</b>. Se il cliente ha ancora meno di 26 anni non pagherà il canone; al compimento dei 26 anni sarà applicato, dal mese successivo a quello di scadenza annuale della carta, il canone di <b>26,90 euro</b> (derogabile a <b>9,90 euro</b> solo attraverso un intervento in Price da parte della filiale). [1068]
#
# Summary: 45 correct results out of 100 (45.0%)
# CPU times: total: 906 ms
# Wall time: 7min 19s

# %%
# %%time

invoke_openai (method="http", iterations=100)
# Out:
# >>>> 1 (http) - WRONG: La carta giovani nazionale è la Carta Superflash, una carta prepagata nominativa ricaricabile destinata ai giovani maggiorenni, studenti o lavoratori. La carta può essere sottoscritta esclusivamente da maggiorenni che possiedono un Codice Fiscale valido e che abbiano sottoscritto il Servizio a distanza e firme elettroniche - My Key.
#
# La Carta Superflash permette di:
#
# - Disporre e ricevere bonifici (non è possibile ricevere bonifici di importo inferiore a 1,00 euro).
# - Pagare presso gli esercizi commerciali.
# - Acquistare su Internet senza ancora possedere un conto corrente.
#
# Non può essere rilasciata a minori o incapaci. [1203]
#
# >>>> 2 (http) - WRONG: La carta giovani nazionale, prendendo come riferimento la Superflash, è una carta prepagata nominativa ricaricabile destinata ai giovani, studenti o lavoratori, e a tutti coloro che desiderano disporre e ricevere bonifici (non è possibile ricevere bonifici di importo inferiore a 1,00 euro), pagare presso gli esercizi commerciali e acquistare su Internet senza ancora possedere un conto corrente. Non può essere rilasciata a minori o incapaci [1203].
#
# Al compimento del 18° anno il minore può riscattare il bonus giovani visibile nella Dashboard, che è una somma di denaro accumulata nel tempo [969]. Inoltre, dal 27 maggio 2023 al 30 novembre 2023 i giovani usufruiscono di una promozione che azzera il canone mensile base del Xme Conto monointestato e il canone mensile della XME Card Plus fino alla fine del mese del compimento del trentacinquesimo anno di età [815].
#
# >>>> 3 (http) - CORRECT: La carta giovani nazionale non è menzionata nelle fonti fornite. Per favore, fornisci maggiori dettagli o specifica meglio la tua richiesta.
#
# Come Co-pilota dei Gestori di Filiale Digitale mi occupo di altri argomenti, per approfondirli consulta la Guida ai contenuti. Se vuoi chiedimi qualcos'altro e proverò a risponderti.
#
# >>>> 4 (http) - CORRECT: Come Co-pilota dei Gestori di Filiale Digitale mi occupo di altri argomenti, per approfondirli consulta la Guida ai contenuti. Se vuoi chiedimi qualcos'altro e proverò a risponderti.
#
# >>>> 5 (http) - CORRECT: Come Co-pilota dei Gestori di Filiale Digitale mi occupo di altri argomenti, per approfondirli consulta la Guida ai contenuti. Se vuoi chiedimi qualcos'altro e proverò a risponderti.
#
# >>>> 6 (http) - WRONG: La carta destinata ai giovani menzionata nelle mie fonti è la Carta XME Card Plus e la Carta Superflash. Ecco alcune informazioni rilevanti:
#
# 1. **Carta XME Card Plus:**
#    - Dal **27 maggio 2023** al **30 novembre 2023**, i giovani possono usufruire di una promozione che azzera il canone mensile della XME Card Plus e del Xme Conto monointestato fino alla fine del mese del compimento del trentacinquesimo anno di età [815].
#
# 2. **Carta Superflash:**
#    - Rivolta esclusivamente ai maggiorenni con un Codice Fiscale valido e che abbiano sottoscritto il Servizio a distanza e firme elettroniche - My Key.
#    - Destinata ai giovani, studenti o lavoratori, permette di disporre e ricevere bonifici (non inferiori a 1,00 euro), pagare presso esercizi commerciali e acquistare online senza possedere un conto corrente.
#    - NON può essere rilasciata a minori [1203].
#
# 3. **Promozioni specifiche per i giovani:**
#    - Fino al **35º anno di età**, il cliente può beneficiare di promozioni che includono azzeramento del canone mensile e altre agevolazioni [815][1530].
#    - Dal **01 luglio 2020** in aggiunta, azzerato il costo di rinnovo della XME Card Plus e quello per ogni singolo assegno bancario addebitato [814].
#
# Per ulteriori dettagli, ti consiglio di consultare la Guida ai contenuti sul sito della Banca Intesa Sanpaolo.
#
# >>>> 7 (http) - CORRECT: Come Co-pilota dei Gestori di Filiale Digitale mi occupo di altri argomenti, per approfondirli consulta la Guida ai contenuti. Se vuoi chiedimi qualcos'altro e proverò a risponderti.
#
# >>>> 8 (http) - CORRECT: Come Co-pilota dei Gestori di Filiale Digitale mi occupo di altri argomenti, per approfondirli consulta la Guida ai contenuti. Se vuoi chiedimi qualcos'altro e proverò a risponderti.
#
# >>>> 9 (http) - CORRECT: Come Co-pilota dei Gestori di Filiale Digitale mi occupo di altri argomenti, per approfondirli consulta la Guida ai contenuti. Se vuoi chiedimi qualcos'altro e proverò a risponderti.
#
# >>>> 10 (http) - WRONG: La carta Superflash è una carta prepagata nominativa ricaricabile destinata principalmente ai giovani, studenti o lavoratori, e a tutti coloro che desiderano disporre e ricevere bonifici, pagare presso gli esercizi commerciali e acquistare su Internet senza ancora possedere un conto corrente. **Non può essere rilasciata a minori o incapaci**. [1203]
#
# Qualora la carta venga utilizzata sui circuiti internazionali (Visa/Mastercard) e si digiti per 3 volte consecutive un PIN errato, la carta sarà bloccata ed eventualmente catturata dallo sportello ATM bancomat. Tuttavia, se il blocco è presente solo sul circuito nazionale, le operazioni richieste su circuito internazionale sono regolarmente autorizzate. È necessaria la verifica dello stato riportato in Webcard per capire il comportamento corretto da attuare. [384]
#
# >>>> 11 (http) - WRONG: Per la carta Superflash, specificamente voluta per i giovani, studenti o lavoratori, e per chi desidera gestire operazioni finanziarie come bonifici e pagamenti senza possedere un conto corrente, ci sono alcune informazioni chiave:
#
# - **Target**: Destinata ai maggiorenni con Codice Fiscale valido, sottoscrittori del Servizio a distanza e firme elettroniche - My Key.
# - **Uso**: Permette di inviare e ricevere bonifici (non inferiore a 1,00 euro), pagare presso gli esercizi commerciali e acquistare online.
# - **Non rilasciabile**: Ai minori o incapaci.
# - **Promozioni**: Se emessa in convenzione UNDER26 prima del 30 settembre 2017, al compimento dei 26 anni il canone annuo applicato sarà di 26,90 euro, salvo deroghe tramite filiale.
#
# Queste sono le caratteristiche principali della carta Superflash destinata ai giovani. [1203][1068]
#
# >>>> 12 (http) - CORRECT: Come Co-pilota dei Gestori di Filiale Digitale mi occupo di altri argomenti, per approfondirli consulta la Guida ai contenuti. Se vuoi chiedimi qualcos'altro e proverò a risponderti.
#
# >>>> 13 (http) - CORRECT: Come Co-pilota dei Gestori di Filiale Digitale mi occupo di altri argomenti, per approfondirli consulta la Guida ai contenuti. Se vuoi chiedimi qualcos'altro e proverò a risponderti.
#
# >>>> 14 (http) - CORRECT: Come Co-pilota dei Gestori di Filiale Digitale mi occupo di altri argomenti, per approfondirli consulta la Guida ai contenuti. Se vuoi chiedimi qualcos'altro e proverÃ² a risponderti.
#
# {"error":{"code":"429","message": "Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2024-05-01-preview have exceeded token rate limit of your current OpenAI S0 pricing tier. Please retry after 12 seconds. Please go here: https://aka.ms/oai/quotaincrease if you would like to further increase the default rate limit."}}
